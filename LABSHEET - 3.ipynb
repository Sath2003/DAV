# %% [markdown]
# PIE CHARTS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# RECOMMENDED TO USE WHEN WE HAVE 5 OR LESS VALUES TO PLOT
#
# Plotting the pie chart graph

# %%
slice=[30,40,20,50]

# %%
plt.pie(slice)
# Out:
# ([<matplotlib.patches.Wedge at 0x7efd7f01d000>,
#   <matplotlib.patches.Wedge at 0x7efd7f01cf10>,
#   <matplotlib.patches.Wedge at 0x7efd7f01d840>,
#   <matplotlib.patches.Wedge at 0x7efd7f01dcc0>],
#  [Text(0.8600146261281999, 0.6858387877960626, ''),
#   Text(-0.6858388280562522, 0.8600145940217683, ''),
#   Text(-0.991065700431763, -0.47727222570321337, ''),
#   Text(0.4772722720983461, -0.9910656780890369, '')])
